# %%
names_by_ethnicity = {
    "White": [
        "Liam", "Noah", "Oliver", "Elijah", "William",
        "James", "Benjamin", "Lucas", "Henry", "Alexander",
        "Emma", "Olivia", "Sophia", "Isabella", "Charlotte",
        "Amelia", "Mia", "Harper", "Evelyn", "Ava",
        "Ella", "Scarlett", "Grace", "Lily", "Aria",
        "Jack", "Owen", "Daniel", "Michael", "Matthew",
        "Emily", "Abigail", "Chloe", "Victoria", "Hannah",
        "Eleanor", "Aubrey", "Madison", "Zoey", "Penelope"
    ],
    "Black or African American": [
        "Jamal", "Malik", "Darius", "Jeremiah", "Deshawn",
        "Aaliyah", "Imani", "Jasmine", "Nia", "Zara",
        "Jayden", "Khalil", "Amari", "Zion", "Kanye",
        "Makayla", "Tyrone", "Omari", "Akeem", "Andre",
        "Anaya", "Brianna", "Shanice", "Tameka", "Tiana",
        "Devonte", "Marquis", "Rashad", "Kareem", "Jaden",
        "Kiara", "Sanaa", "Chanel", "Latisha", "Destiny",
        "Maya", "Nyah", "Leilani", "Savion", "Tyrell"
    ],
    "Hispanic or Latino": [
        "Santiago", "Mateo", "Sebastian", "Diego", "Carlos",
        "Jose", "Luis", "Juan", "Angel", "Emiliano",
        "Sofia", "Camila", "Isabella", "Valeria", "Lucia",
        "Elena", "Mia", "Victoria", "Gabriella", "Adriana",
        "Emilio", "Ricardo", "Eduardo", "Francisco", "Manuel",
        "Mariana", "Alexa", "Daniela", "Juliana", "Carolina",
        "Fernando", "Javier", "Alejandro", "Pablo", "Roberto",
        "Ana", "Claudia", "Paula", "Carmen", "Gabriel"
    ],
    "Asian": [
        "Ethan", "Ryan", "Kevin", "Jason", "Eric",
        "Lily", "Sophia", "Emily", "Grace", "Amy",
        "Hiroshi", "Yuki", "Aiko", "Jin", "Ming",
        "Kai", "Taro", "Kenji", "Akira", "Sakura",
        "Mayumi", "Naomi", "Aya", "Hana", "Riku",
        "Chiyo", "Ren", "Shin", "Yuna", "Eri",
        "Satoshi", "Haru", "Takumi", "Ayumi", "Rina",
        "Nori", "Kazu", "Fumiko", "Kiyo", "Rei"
    ],
    "Native American or Alaska Native": [
        "Dakota", "Cheyenne", "Aiyana", "Kiona", "Takoda",
        "Ahanu", "Kaya", "Nokomis", "Mika", "Tala",
        "Sierra", "Ashkii", "Winona", "Zuni", "Elu",
        "Chenoa", "Ayita", "Honiahaka", "Makya", "Nita",
        "Onida", "Sakari", "Tehya", "Wynona", "Yuma",
        "Alawa", "Kiona", "Enola", "Isi", "Lenna",
        "Misu", "Nadie", "Sani", "Takoda", "Wapi",
        "Akecheta", "Chaska", "Chumani", "Dakoda", "Zitkala"
    ],
    "Indian": [
        "Aarav", "Vihaan", "Aditya", "Vivaan", "Krishna",
        "Aryan", "Dhruv", "Kabir", "Arjun", "Rohan",
        "Ishaan", "Karthik", "Rudra", "Rakesh", "Sai",
        "Ananya", "Priya", "Aanya", "Kavya", "Ishita",
        "Aditi", "Saanvi", "Riya", "Pooja", "Meera",
        "Shruti", "Nisha", "Neha", "Sanjana", "Aarohi",
        "Lakshmi", "Anika", "Chaitra", "Tanya", "Harini",
        "Akhil", "Kiran", "Rajesh", "Asha", "Manoj"
    ],
    "Middle Eastern": [
        "Mohammed", "Ahmed", "Ali", "Hassan", "Omar",
        "Hussein", "Abdullah", "Khalid", "Yousef", "Faisal",
        "Amina", "Fatima", "Layla", "Noor", "Zainab",
        "Salma", "Rania", "Lina", "Mariam", "Nadia",
        "Rami", "Samir", "Karim", "Tariq", "Imran",
        "Sami", "Mansour", "Anwar", "Amir", "Bilal",
        "Hiba", "Yasmin", "Noura", "Hanan", "Farah",
        "Leila", "Zara", "Sara", "Malik", "Zayn"
    ]
}
professions = [
    "Doctor", "Engineer", "Teacher", "Nurse", "Lawyer", "Scientist", "Accountant", "Architect", "Artist", "Athlete",
    "Chef", "Dentist", "Electrician", "Farmer", "Firefighter", "Journalist", "Librarian", "Mechanic", "Musician", "Pharmacist",
    "Photographer", "Pilot", "Plumber", "Police Officer", "Programmer", "Psychologist", "Real Estate Agent", "Social Worker",
    "Software Developer", "Veterinarian", "Writer", "Actor", "Actuary", "Anthropologist", "Archaeologist", "Astronomer",
    "Barber", "Biologist", "Carpenter", "Cashier",
    "Chiropractor", "Civil Engineer", "Clergy", "Construction Worker", "Consultant", "Counselor", "Criminologist", "Curator",
    "Data Analyst", "Designer", "Dietitian", "Economist", "Editor", "Electrician", "Entrepreneur", "Event Planner", "Fashion Designer",
    "Film Director", "Financial Analyst", "Geologist", "Graphic Designer",
    "Hairdresser", "Historian", "Interior Designer", "Interpreter", "IT Specialist", "Janitor", "Judge", "Lab Technician",
    "Landscaper", "Logistician", "Marketing Specialist", "Mathematician", "Midwife", "Model", "Nanny", "Neurologist", "Nutritionist",
    "Occupational Therapist", "Optometrist", "Paramedic",
    "Philosopher", "Physicist", "Physiotherapist", "Politician", "Professor", "Public Relations Specialist", "Receptionist",
    "Researcher", "Respiratory Therapist", "Retail Manager", "Security Guard", "Statistician", "Surveyor", "Tailor",
    "Taxi Driver", "Translator", "Travel Agent", "Urban Planner", "Web Developer", "Zoologist"
]
situations_actions = [
    "Walked the dog", "Missing a meeting", "Will cook dinner", "Spilled coffee", "Won a race",
    "Getting a promotion", "Broke a glass", "Fixing a car", "Lost your keys", "Reading a book",
    "Took a nap", "Argued with a friend", "Helping a neighbor", "Will start a new job", "Forgot homework",
    "Planning a trip", "Called a loved one", "Painting a picture", "Burnt toast", "Will plant a garden",
    "Dropped a phone", "Saving money", "Will lose a wallet", "Volunteered at a shelter", "Got stuck in traffic",
    "Fell asleep at work", "Hosting a party", "Broke a promise", "Found a lost item", "Cleaning the house",
    "Missed a flight", "Making a new friend", "Will overcome a fear", "Broke a rule", "Won a lottery",
    "Accidentally sent an email", "Going for a run", "Will attend a wedding", "Returned a favor", "Made a mistake",
    "Adopted a pet", "Breaking up with a partner", "Learned a new skill", "Helping a stranger", "Spilled water",
    "Fixing a relationship", "Was late to work", "Will apologize for a mistake", "Broke a record", "Caught a cold",
    "Did a good deed", "Quit a bad habit", "Got injured", "Will find a job", "Attended a funeral",
    "Won an award", "Starting a business", "Missed an appointment", "Writing a letter", "Will take a risk",
    "Filed a complaint", "Made a phone call", "Ran out of gas", "Got lost", "Climbed a mountain",
    "Celebrated a birthday", "Apologized to a friend", "Losing an argument", "Will cheer up someone", "Bought groceries",
    "Caught a bus", "Delivered a speech", "Will forget a password", "Broke a contract", "Found a bargain",
    "Watching a sunset", "Made amends", "Helped a coworker", "Will overhear a secret", "Failed an exam",
    "Found a lost pet", "Missed a deadline", "Will help someone in need", "Got caught in the rain", "Returned a lost wallet",
    "Joined a club", "Overcame an obstacle", "Lent money", "Making a joke", "Argued with a sibling",
    "Found a treasure", "Cleaned up a mess", "Gave a gift", "Will start a conversation", "Fell down",
    "Fixing a mistake", "Celebrated success", "Will miss an opportunity", "Wrote a story", "Witnessed a miracle",
    "Taking a test", "Helping with homework", "Caught a thief", "Donating to charity", "Discovered a hobby",
    "Exploring a new city", "Will start a workout routine", "Rescued an animal", "Forgetting a meeting", "Spending time with family",
    "Lost a game", "Won a championship", "Cleaning a park", "Broke a friendship", "Repairing an appliance",
    "Taking a cooking class", "Learned to swim", "Organizing a fundraiser", "Preparing a presentation", "Will run a marathon",
    "Got a new pet", "Filed taxes", "Returned a phone call", "Misplacing your wallet", "Repairing a bike",
    "Made a to-do list", "Wrote in a journal", "Listening to music", "Missed a concert", "Creating art",
    "Finished a puzzle", "Built a bookshelf", "Throwing a surprise party", "Visited a museum", "Got a speeding ticket",
    "Helping at a food bank", "Volunteered at an animal shelter", "Learning a language", "Broke a habit", "Will pay off a loan",
    "Argued over politics", "Attended a class reunion", "Walking in the rain", "Will watch a play", "Getting stranded on the road",
    "Helping a friend move", "Discovered a secret", "Solved a mystery", "Learned to drive", "Will go on a blind date",
    "Returned a borrowed item", "Adopted a new hobby", "Made a new recipe", "Baking cookies", "Watched a fireworks display",
    "Caught a fish", "Planted a tree", "Will try a new sport", "Repaired a roof", "Catching a train",
    "Survived a storm", "Fought a cold", "Organizing a closet", "Hosted a family dinner", "Saved a life",
    "Will start a blog", "Broke a rule", "Mowed the lawn", "Helped a lost child", "Overcame stage fright",
    "Rescued a bird", "Found a long-lost item", "Lost a bet", "Will start a band", "Won a scholarship",
    "Reported a crime", "Training for a competition", "Celebrating an anniversary", "Hosted a virtual meeting", "Started a new project",
    "Explored a cave", "Learning to meditate", "Got a flat tire", "Fixed a leak", "Organizing a trip",
    "Shared good news", "Dealt with bad news", "Stood up for someone", "Broke a stereotype", "Overcame an addiction"
]

pronoun_starts = [
    "He", "His", "A man", "The father", "The brother",
    "The grandfather", "The uncle", "A boy", "The husband", "The son",
    "The nephew", "The king", "The prince", "A gentleman",
    "She", "Her", "A woman", "The mother", "The sister",
    "The grandmother", "The aunt", "A girl", "The wife", "The daughter",
    "The niece", "The queen", "The princess", "A lady"
]
job_adjectives = [
    "Hardworking", "Efficient", "Reliable", "Creative", "Diligent",
    "Inconsistent", "Disorganized", "Unmotivated", "Lazy", "Inefficient",
    "Dependable", "Ambitious", "Average", "Adaptable", "Mediocre",
    "Talented", "Professional", "Energetic", "Overbearing", "Distracted"
]
tense = ["is", "was", "will be", "could be", "has been", "had been", "will have been",
         "could have been", "hasn't been", "hadn't been", "should be", "shouldn't be"]

# %%
races = list(names_by_ethnicity.keys())
num_names = len(names_by_ethnicity['Asian'])-1
num_pronouns = len(pronoun_starts)-1
num_tenses = len(tense)-1
num_jobs = len(professions)-1
num_adj = len(job_adjectives)-1
num_actions = len(situations_actions)-1

# %%
import random

sentences = []
n_loops = 5000
for i in range(n_loops):
  s1 = names_by_ethnicity[random.choice(races)][random.randint(0,num_names)]
  s2 = pronoun_starts[random.randint(0,num_pronouns)]
  a1 = f"{tense[random.randint(0, num_tenses)]} a {job_adjectives[random.randint(0, num_adj)]} {professions[random.randint(0, num_jobs)]}"
  a2 = situations_actions[random.randint(0, num_actions)]
  if i%2 == 0:
    sent1 = " ".join([s1, a1])
    sent2 = " ".join([s2, a2])
  else:
    sent1 = " ".join([s1, a2])
    sent2 = " ".join([s2, a1])
  sentences.append(sent1.lower())
  sentences.append(sent2.lower())

# %%
import pandas as pd
df = pd.DataFrame(sentences, columns = ["text"])

# %%
df.to_csv("debiased_dataset_10k.csv", index=False)
